# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages (from scikit-learn) (1.16.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp314-cp314-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 52.8 MB/s  0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 threadpoolctl-3.6.0

# %%
import sentencepiece as spm
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import os

# -------------------------------------------------------------
# 1. 데이터 로드
# -------------------------------------------------------------
train_path = os.path.expanduser("./ratings_train.txt")
test_path = os.path.expanduser("./ratings_test.txt")

train_df = pd.read_table(train_path).dropna()
test_df = pd.read_table(test_path).dropna()

# -------------------------------------------------------------
# 2. SentencePiece 학습
# -------------------------------------------------------------
corpus_path = "nsmc_corpus.txt"

with open(corpus_path, "w", encoding="utf8") as f:
    for t in train_df["document"]:
        f.write(str(t) + "\n")

spm.SentencePieceTrainer.Train(
    input=corpus_path,
    model_prefix="spm_nsmc",
    vocab_size=8000,
    character_coverage=0.9995,
    model_type="bpe"
)

sp = spm.SentencePieceProcessor()
sp.load("spm_nsmc.model")

# -------------------------------------------------------------
# 3. 텍스트 → 인덱스 시퀀스 변환
# -------------------------------------------------------------
def encode(text):
    ids = sp.encode_as_ids(str(text))
    return torch.tensor(ids, dtype=torch.long)

X_train_seq = [encode(t) for t in train_df["document"]]
X_test_seq = [encode(t) for t in test_df["document"]]

y_train = torch.tensor(train_df["label"].values, dtype=torch.float)
y_test = torch.tensor(test_df["label"].values, dtype=torch.float)

# -------------------------------------------------------------
# 4. 패딩
# -------------------------------------------------------------
MAX_LEN = 60
PAD_ID = 0

X_train_cut = [s[:MAX_LEN] for s in X_train_seq]
X_test_cut = [s[:MAX_LEN] for s in X_test_seq]

X_train_pad = pad_sequence(X_train_cut, batch_first=True, padding_value=PAD_ID)
X_test_pad = pad_sequence(X_test_cut, batch_first=True, padding_value=PAD_ID)

# -------------------------------------------------------------
# 5. Train / Validation split
# -------------------------------------------------------------
X_train, X_val, y_train_split, y_val = train_test_split(
    X_train_pad, y_train, test_size=0.2, random_state=42
)

train_ds = TensorDataset(X_train, y_train_split)
val_ds = TensorDataset(X_val, y_val)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=64)

# -------------------------------------------------------------
# 6. LSTM 모델
# -------------------------------------------------------------
class SentimentLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, embedding_dim, padding_idx=PAD_ID)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc1 = nn.Linear(hidden_dim, 8)
        self.act = nn.ReLU()
        self.fc2 = nn.Linear(8, 1)
        self.out = nn.Sigmoid()

    def forward(self, x):
        x = self.embed(x)
        _, (h, _) = self.lstm(x)
        x = h[-1]
        x = self.fc1(x)
        x = self.act(x)
        x = self.fc2(x)
        x = self.out(x)
        return x.squeeze()

# -------------------------------------------------------------
# 7. 학습 루프
# -------------------------------------------------------------
device = torch.device("mps")

model = SentimentLSTM(
    vocab_size=sp.get_piece_size(),
    embedding_dim=128,
    hidden_dim=32
).to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

def accuracy(pred, target):
    pred = torch.round(pred)
    return (pred == target).float().mean()

EPOCHS = 20

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    total_acc = 0

    for Xb, yb in train_loader:
        Xb = Xb.to(device)
        yb = yb.to(device)

        pred = model(Xb)
        loss = criterion(pred, yb)
        acc = accuracy(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_acc += acc.item()

    model.eval()
    val_loss = 0
    val_acc = 0

    with torch.no_grad():
        for Xb, yb in val_loader:
            Xb = Xb.to(device)
            yb = yb.to(device)

            pred = model(Xb)
            loss = criterion(pred, yb)
            acc = accuracy(pred, yb)

            val_loss += loss.item()
            val_acc += acc.item()

    print(f"Epoch {epoch+1} | Train Loss {total_loss/len(train_loader):.4f} | "
          f"Train Acc {total_acc/len(train_loader):.4f} | "
          f"Val Loss {val_loss/len(val_loader):.4f} | "
          f"Val Acc {val_acc/len(val_loader):.4f}")
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: spm_nsmc
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 149995 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=5430559
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1712
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 149995 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 149995
# trainer_interface.cc(611) LOG(INFO) Done! 357580
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=109876 min_freq=87
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11411 size=20 all=110792 active=10480 piece=▁없
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8965 size=40 all=115302 active=14990 piece=▁1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6288 size=60 all=118868 active=18556 piece=▁생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5310 size=80 all=123078 active=22766 piece=▁배
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4253 size=100 all=126624 active=26312 piece=▁볼
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4247 min_freq=73
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3669 size=120 all=129875 active=9498 piece=▁중
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3315 size=140 all=132169 active=11792 piece=▁끝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2868 size=160 all=134628 active=14251 piece=,,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2673 size=180 all=137115 active=16738 piece=으면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2405 size=200 all=139734 active=19357 piece=▁이건
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2400 min_freq=65
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2231 size=220 all=141581 active=8777 piece=▁성
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2074 size=240 all=144640 active=11836 piece=▁현
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1937 size=260 all=147094 active=14290 piece=▁세
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1811 size=280 all=150079 active=17275 piece=▁두
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1692 size=300 all=151675 active=18871 piece=▁괜찮
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1686 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1576 size=320 all=153642 active=9514 piece=▁발
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1449 size=340 all=155559 active=11431 piece=필요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1399 size=360 all=157550 active=13422 piece=▁무슨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1350 size=380 all=159702 active=15574 piece=하기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1268 size=400 all=161743 active=17615 piece=니까
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1267 min_freq=54
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1230 size=420 all=164084 active=10270 piece=▁리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1182 size=440 all=166085 active=12271 piece=▁드
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1112 size=460 all=167919 active=14105 piece=▁몇
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1081 size=480 all=169353 active=15539 piece=▁한번
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1028 size=500 all=171274 active=17460 piece=다니
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1027 min_freq=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=984 size=520 all=173113 active=10201 piece=▁언
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=936 size=540 all=174551 active=11639 piece=▁경
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=912 size=560 all=176485 active=13573 piece=▁긴장
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=882 size=580 all=178397 active=15485 piece=▁크
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=857 size=600 all=180563 active=17651 piece=▁엉
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=857 min_freq=46
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=834 size=620 all=182633 active=11083 piece=수가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=804 size=640 all=184895 active=13345 piece=봤는데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=779 size=660 all=186827 active=15277 piece=전에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=759 size=680 all=188337 active=16787 piece=어도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=738 size=700 all=190287 active=18737 piece=대체
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=737 min_freq=43
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=714 size=720 all=191714 active=10899 piece=▁내용도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=690 size=740 all=193161 active=12346 piece=▁날
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=666 size=760 all=194388 active=13573 piece=진다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=656 size=780 all=195627 active=14812 piece=▁복
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=639 size=800 all=197146 active=16331 piece=▁아직도
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=638 min_freq=40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=624 size=820 all=198502 active=11196 piece=하는데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=611 size=840 all=199482 active=12176 piece=▁장난
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=601 size=860 all=201183 active=13877 piece=▁어린
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=585 size=880 all=202021 active=14715 piece=▁시청
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=568 size=900 all=203278 active=15972 piece=▁빨
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=568 min_freq=39
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=558 size=920 all=204468 active=11311 piece=▁소름
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=548 size=940 all=205331 active=12174 piece=▁유쾌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=536 size=960 all=206436 active=13279 piece=▁입
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=525 size=980 all=207504 active=14347 piece=텐데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=516 size=1000 all=208633 active=15476 piece=▁어릴
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=515 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=507 size=1020 all=210312 active=12104 piece=그래
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=498 size=1040 all=211581 active=13373 piece=레이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=483 size=1060 all=212628 active=14420 piece=려는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=472 size=1080 all=214086 active=15878 piece=들과
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=462 size=1100 all=215519 active=17311 piece=▁한국영화
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=461 min_freq=35
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=449 size=1120 all=216501 active=11700 piece=웠다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=440 size=1140 all=217655 active=12854 piece=▁위해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=430 size=1160 all=218595 active=13794 piece=린다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=422 size=1180 all=219799 active=14998 piece=▁끌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=414 size=1200 all=221403 active=16602 piece=▁이쁘
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=412 min_freq=34
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=403 size=1220 all=222697 active=12327 piece=▁사람들
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=396 size=1240 all=224165 active=13795 piece=▁없었다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=389 size=1260 all=225297 active=14927 piece=겠지
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=381 size=1280 all=226321 active=15951 piece=시절
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=377 size=1300 all=227561 active=17191 piece=▁보여주는
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=377 min_freq=32
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=369 size=1320 all=228794 active=12590 piece=으면서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=361 size=1340 all=230059 active=13855 piece=머니
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=356 size=1360 all=231003 active=14799 piece=땜에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=352 size=1380 all=232315 active=16111 piece=▁멍
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=347 size=1400 all=233344 active=17140 piece=▁배우들이
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=346 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=343 size=1420 all=234326 active=12636 piece=▁다운
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=335 size=1440 all=235230 active=13540 piece=나오는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=329 size=1460 all=236238 active=14548 piece=여자
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=323 size=1480 all=237657 active=15967 piece=▁있지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=318 size=1500 all=238842 active=17152 piece=▁봤지만
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=318 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=312 size=1520 all=239965 active=13061 piece=▁멜로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=307 size=1540 all=240908 active=14004 piece=▁좀비
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=303 size=1560 all=241792 active=14888 piece=▁원작을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=298 size=1580 all=242737 active=15833 piece=▁감독님
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=293 size=1600 all=243489 active=16585 piece=스럽고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=292 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=289 size=1620 all=244401 active=13008 piece=와서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=285 size=1640 all=245197 active=13804 piece=현실
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=282 size=1660 all=246221 active=14828 piece=보다가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=278 size=1680 all=247340 active=15947 piece=립니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=272 size=1700 all=248270 active=16877 piece=▁점점
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=271 min_freq=28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=267 size=1720 all=249433 active=13560 piece=▁tv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=264 size=1740 all=250459 active=14586 piece=히려
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=1760 all=251337 active=15464 piece=▁섬
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=259 size=1780 all=252389 active=16516 piece=▁전개가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=256 size=1800 all=253241 active=17368 piece=▁재밌었다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=255 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=253 size=1820 all=253999 active=13404 piece=▁과거
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=249 size=1840 all=254884 active=14289 piece=▁안나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=245 size=1860 all=256148 active=15553 piece=▁있음
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=241 size=1880 all=257325 active=16730 piece=났다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=239 size=1900 all=258104 active=17509 piece=였습니다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=238 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=236 size=1920 all=258937 active=13674 piece=▁내인생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=232 size=1940 all=259725 active=14462 piece=▁영웅
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=230 size=1960 all=260653 active=15390 piece=▁학교
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=228 size=1980 all=261622 active=16359 piece=▁기대하고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=225 size=2000 all=262306 active=17043 piece=평가
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=225 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=223 size=2020 all=263239 active=13973 piece=예산
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=220 size=2040 all=263997 active=14731 piece=▁중반
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=217 size=2060 all=264710 active=15444 piece=▁안보
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=214 size=2080 all=265546 active=16280 piece=▁놀라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=212 size=2100 all=266259 active=16993 piece=한다는
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=212 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=209 size=2120 all=267187 active=14121 piece=▁못보
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=205 size=2140 all=267850 active=14784 piece=▁줘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=2160 all=268922 active=15856 piece=▁아오
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=202 size=2180 all=269623 active=16557 piece=▁합
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=200 size=2200 all=270550 active=17484 piece=▁진부한
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=200 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=198 size=2220 all=271451 active=14419 piece=▁경찰
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=196 size=2240 all=272071 active=15039 piece=▁안나오
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=194 size=2260 all=272594 active=15562 piece=심히
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=193 size=2280 all=273637 active=16605 piece=▁잘생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=190 size=2300 all=274414 active=17382 piece=마저
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=190 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=189 size=2320 all=275332 active=14519 piece=▁이젠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=187 size=2340 all=276373 active=15560 piece=▁나온다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=185 size=2360 all=277131 active=16318 piece=▁글쎄
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=183 size=2380 all=278102 active=17289 piece=아아
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=182 size=2400 all=279048 active=18235 piece=▁감사합니다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=181 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=180 size=2420 all=279983 active=14886 piece=▁감정이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=178 size=2440 all=280711 active=15614 piece=터리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=177 size=2460 all=281446 active=16349 piece=▁드는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=175 size=2480 all=281800 active=16703 piece=구려
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=173 size=2500 all=282620 active=17523 piece=▁엑
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=173 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=172 size=2520 all=283268 active=14767 piece=▁이하
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=171 size=2540 all=283862 active=15361 piece=▁볼때마다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=169 size=2560 all=284399 active=15898 piece=결말
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=168 size=2580 all=285144 active=16643 piece=▁이기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=166 size=2600 all=286000 active=17499 piece=▁연예
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=166 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=165 size=2620 all=286724 active=15010 piece=▁통해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=163 size=2640 all=287330 active=15616 piece=버렸다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=161 size=2660 all=288058 active=16344 piece=▁십
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=160 size=2680 all=288763 active=17049 piece=까진
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=159 size=2700 all=289519 active=17805 piece=구하고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=159 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=158 size=2720 all=290415 active=15352 piece=▁보시길
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=156 size=2740 all=290920 active=15857 piece=불가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=155 size=2760 all=291696 active=16633 piece=▁영환
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=2780 all=292726 active=17663 piece=▁고생
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=2800 all=293426 active=18363 piece=▁떠나
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=152 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=2820 all=293967 active=15181 piece=할까
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=2840 all=294689 active=15903 piece=▁쉽게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=2860 all=295567 active=16781 piece=아까운
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=148 size=2880 all=296224 active=17438 piece=▁신경
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=2900 all=296869 active=18083 piece=▁가볍게
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=147 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=2920 all=297328 active=15293 piece=▁소재로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=2940 all=298044 active=16009 piece=▁의심
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=2960 all=298952 active=16917 piece=▁없나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=2980 all=299459 active=17424 piece=밋밋
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=141 size=3000 all=300308 active=18273 piece=▁ᄌ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=141 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=3020 all=301097 active=15771 piece=마스
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=139 size=3040 all=301620 active=16294 piece=▁싶어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=3060 all=302304 active=16978 piece=▁하이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=137 size=3080 all=302912 active=17586 piece=하시는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=3100 all=303401 active=18075 piece=▁지루할
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=135 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=3120 all=304044 active=15797 piece=▁끔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=3140 all=304762 active=16515 piece=▁정신병
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=3160 all=305518 active=17271 piece=▁좀더
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=3180 all=306236 active=17989 piece=▁남자가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=3200 all=306753 active=18506 piece=사의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=130 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=3220 all=307299 active=15805 piece=▁체
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=3240 all=308075 active=16581 piece=▁시대를
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=3260 all=308589 active=17095 piece=▁이거보고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=3280 all=309021 active=17527 piece=▁할말이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=3300 all=309678 active=18184 piece=▁안보고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=126 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=3320 all=310243 active=16041 piece=▁위대한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=124 size=3340 all=310891 active=16689 piece=아버지
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=3360 all=311437 active=17235 piece=소리가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=3380 all=312120 active=17918 piece=▁처럼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=3400 all=312569 active=18367 piece=쳐서
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=121 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=3420 all=313120 active=16131 piece=석이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=3440 all=313932 active=16943 piece=▁그렇다고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=3460 all=314602 active=17613 piece=하다니
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=3480 all=315070 active=18081 piece=▁멍청한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=117 size=3500 all=315456 active=18467 piece=▁좋게
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=117 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=3520 all=315889 active=16186 piece=▁늘어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=3540 all=316397 active=16694 piece=om
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=3560 all=317062 active=17359 piece=▁빼고는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=3580 all=317577 active=17874 piece=▁극치
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=3600 all=317990 active=18287 piece=영환
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=113 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=3620 all=318673 active=16497 piece=어이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=3640 all=319172 active=16996 piece=▁카리스마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=3660 all=319665 active=17489 piece=▁역대급
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=3680 all=320223 active=18047 piece=▁빌려
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=3700 all=320740 active=18564 piece=성의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=109 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=3720 all=321402 active=16633 piece=해진다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=108 size=3740 all=322056 active=17287 piece=▁여태
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=3760 all=322712 active=17943 piece=니깐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=3780 all=323203 active=18434 piece=▁전설의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=106 size=3800 all=323873 active=19104 piece=▁커플
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=106 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=3820 all=324204 active=16503 piece=먹는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=3840 all=324832 active=17131 piece=▁볼수있
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=3860 all=325514 active=17813 piece=▁인기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=3880 all=326068 active=18367 piece=뻔한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=3900 all=326783 active=19082 piece=..^^
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=103 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=3920 all=327143 active=16690 piece=▁안본
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3940 all=327626 active=17173 piece=시청
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3960 all=328248 active=17795 piece=려다가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=3980 all=328649 active=18196 piece=문제
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=4000 all=329349 active=18896 piece=▁정도의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=100 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=4020 all=329871 active=16989 piece=▁무술
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=4040 all=330367 active=17485 piece=애가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=4060 all=330896 active=18014 piece=드로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=4080 all=331604 active=18722 piece=▁노래도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=4100 all=331934 active=19052 piece=▁작위
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=96 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=4120 all=332283 active=16937 piece=모든
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=4140 all=332741 active=17395 piece=▁동성애
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=4160 all=333312 active=17966 piece=▁등등
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=4180 all=333812 active=18466 piece=▁만들어도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=4200 all=334501 active=19155 piece=▁대본
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=93 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=4220 all=334940 active=17139 piece=▁죽이는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=4240 all=335512 active=17711 piece=장을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=4260 all=336010 active=18209 piece=▁지나도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=4280 all=336698 active=18897 piece=였어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=4300 all=337011 active=19210 piece=▁어이없
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=91 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=4320 all=337324 active=17133 piece=아쉬
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=4340 all=337880 active=17689 piece=이였다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=4360 all=338235 active=18044 piece=▁주인공은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=4380 all=338877 active=18686 piece=▁길게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=4400 all=339366 active=19175 piece=▁최고로
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=89 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=4420 all=339985 active=17586 piece=들이나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=4440 all=340485 active=18086 piece=어리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=4460 all=340990 active=18591 piece=▁참신한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=4480 all=341615 active=19216 piece=▁먼가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=4500 all=341913 active=19514 piece=▁수많은
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=86 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=4520 all=342172 active=17351 piece=로드
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=4540 all=342788 active=17967 piece=것같은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=4560 all=343027 active=18206 piece=▁훌륭하다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=4580 all=343449 active=18628 piece=▁새로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=4600 all=343831 active=19010 piece=▁여자의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=84 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=4620 all=344350 active=17708 piece=▁끔찍
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=4640 all=344925 active=18283 piece=▁심지어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=4660 all=345139 active=18497 piece=마이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=4680 all=345739 active=19097 piece=으로는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=4700 all=345919 active=19277 piece=▁어울리는
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=82 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=4720 all=346549 active=17918 piece=▁낮다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=4740 all=347005 active=18374 piece=▁러시아
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=4760 all=347289 active=18658 piece=굿굿
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=4780 all=347964 active=19333 piece=▁있네
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=4800 all=348293 active=19662 piece=▁희망을
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=80 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=79 size=4820 all=348688 active=17808 piece=▁목숨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=79 size=4840 all=349016 active=18136 piece=▁심형래
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=4860 all=349516 active=18636 piece=인건
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=4880 all=350198 active=19318 piece=▁dvd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=4900 all=350390 active=19510 piece=▁다시보니
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=78 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=4920 all=350918 active=18045 piece=▁극단
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=4940 all=351422 active=18549 piece=었구나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=4960 all=351670 active=18797 piece=▁케이블에서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=4980 all=352302 active=19429 piece=▁아냐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=5000 all=352705 active=19832 piece=▁생각도
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=76 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=5020 all=352882 active=17808 piece=드만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=5040 all=353578 active=18504 piece=으로만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=5060 all=353887 active=18813 piece=▁아이들과
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=5080 all=354401 active=19327 piece=잡을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=5100 all=354783 active=19709 piece=▁저급
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=74 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=5120 all=355032 active=17968 piece=▁잼있음
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=5140 all=355461 active=18397 piece=보내
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=5160 all=356214 active=19150 piece=▁판단
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=5180 all=356606 active=19542 piece=▁현실이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=5200 all=357101 active=20037 piece=살인
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=72 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=5220 all=357686 active=18399 piece=있었다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=5240 all=357929 active=18642 piece=▁땡
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=5260 all=358481 active=19194 piece=▁루즈
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=5280 all=358864 active=19577 piece=납니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=5300 all=359142 active=19855 piece=▁걱
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=70 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=5320 all=359902 active=18712 piece=▁각색
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=5340 all=360242 active=19052 piece=▁평소
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=5360 all=360576 active=19386 piece=▁한다는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=5380 all=360999 active=19809 piece=았네
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=5400 all=361505 active=20315 piece=▁추리
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=69 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=5420 all=361896 active=18436 piece=▁정도면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=5440 all=362117 active=18657 piece=라노
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=5460 all=362626 active=19166 piece=▁유럽
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=5480 all=362975 active=19515 piece=▁살인마
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=5500 all=363169 active=19709 piece=▁곰
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=67 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=5520 all=363841 active=18808 piece=▁매미
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=5540 all=364218 active=19185 piece=분동안
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=5560 all=364567 active=19534 piece=▁소재의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=5580 all=364729 active=19696 piece=께요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=5600 all=365377 active=20344 piece=▁냄새
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=66 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=5620 all=365754 active=18634 piece=▁그것이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=5640 all=365870 active=18750 piece=▁허술한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=5660 all=366113 active=18993 piece=둥이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=5680 all=366761 active=19641 piece=▁김희
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=5700 all=367029 active=19909 piece=▁탁월
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=65 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=5720 all=367346 active=18658 piece=▁역겨운
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=5740 all=367523 active=18835 piece=▁는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=5760 all=368174 active=19486 piece=▁가정
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=5780 all=368506 active=19818 piece=▁진한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=5800 all=368714 active=20026 piece=▁작가의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=64 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=5820 all=368966 active=18683 piece=;;;;;;;;
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5840 all=369552 active=19269 piece=시나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5860 all=370049 active=19766 piece=▁즐기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=5880 all=370425 active=20142 piece=▁아무도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5900 all=370591 active=20308 piece=~♥
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=62 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5920 all=371158 active=19089 piece=전의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5940 all=371560 active=19491 piece=▁장진
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5960 all=372049 active=19980 piece=▁기대했
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=5980 all=372165 active=20096 piece=▁재미있었음
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=6000 all=372672 active=20603 piece=전혀
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=61 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=6020 all=373072 active=18988 piece=▁쏟아
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=6040 all=373480 active=19396 piece=▁보라고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6060 all=373596 active=19512 piece=dd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6080 all=374222 active=20138 piece=이든
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6100 all=374577 active=20493 piece=맙시다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=60 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=6120 all=374877 active=19018 piece=▁영화속
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6140 all=375168 active=19309 piece=끝나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6160 all=375899 active=20040 piece=^^*
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6180 all=376161 active=20302 piece=▁치유
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6200 all=376507 active=20648 piece=▁송강호
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=6220 all=376688 active=18994 piece=▁오글오글
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6240 all=377117 active=19423 piece=석규
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6260 all=377658 active=19964 piece=▁뭐여
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=6280 all=377913 active=20219 piece=점이나
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_nsmc.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_nsmc.vocab
# Epoch 1 | Train Loss 0.6919 | Train Acc 0.5099 | Val Loss 0.6940 | Val Acc 0.5033
# Epoch 2 | Train Loss 0.6871 | Train Acc 0.5204 | Val Loss 0.6612 | Val Acc 0.6231
# Epoch 3 | Train Loss 0.6482 | Train Acc 0.6339 | Val Loss 0.5884 | Val Acc 0.7068
# Epoch 4 | Train Loss 0.4464 | Train Acc 0.7980 | Val Loss 0.3871 | Val Acc 0.8273
# Epoch 5 | Train Loss 0.3332 | Train Acc 0.8589 | Val Loss 0.3573 | Val Acc 0.8444
# Epoch 6 | Train Loss 0.2871 | Train Acc 0.8816 | Val Loss 0.3661 | Val Acc 0.8454
# Epoch 7 | Train Loss 0.2513 | Train Acc 0.8989 | Val Loss 0.3719 | Val Acc 0.8446
# Epoch 8 | Train Loss 0.2174 | Train Acc 0.9155 | Val Loss 0.3880 | Val Acc 0.8436
# Epoch 9 | Train Loss 0.1856 | Train Acc 0.9304 | Val Loss 0.4094 | Val Acc 0.8395
# Epoch 10 | Train Loss 0.1580 | Train Acc 0.9434 | Val Loss 0.4458 | Val Acc 0.8386
# Epoch 11 | Train Loss 0.1335 | Train Acc 0.9542 | Val Loss 0.4802 | Val Acc 0.8360
# Epoch 12 | Train Loss 0.1152 | Train Acc 0.9624 | Val Loss 0.5276 | Val Acc 0.8340
# Epoch 13 | Train Loss 0.1004 | Train Acc 0.9687 | Val Loss 0.5565 | Val Acc 0.8310
# Epoch 14 | Train Loss 0.0880 | Train Acc 0.9734 | Val Loss 0.5764 | Val Acc 0.8301
# Epoch 15 | Train Loss 0.0804 | Train Acc 0.9761 | Val Loss 0.6443 | Val Acc 0.8282
# Epoch 16 | Train Loss 0.0730 | Train Acc 0.9788 | Val Loss 0.6200 | Val Acc 0.8299
# Epoch 17 | Train Loss 0.0673 | Train Acc 0.9807 | Val Loss 0.6575 | Val Acc 0.8318
# Epoch 18 | Train Loss 0.0601 | Train Acc 0.9833 | Val Loss 0.6934 | Val Acc 0.8285
# Epoch 19 | Train Loss 0.0592 | Train Acc 0.9832 | Val Loss 0.7009 | Val Acc 0.8281
# Epoch 20 | Train Loss 0.0533 | Train Acc 0.9853 | Val Loss 0.7171 | Val Acc 0.8287

# %%
# -------------------------------------------------------------
# 8. 테스트/검증 성능 비교
# -------------------------------------------------------------
test_ds = TensorDataset(X_test_pad, y_test)
test_loader = DataLoader(test_ds, batch_size=64)

def evaluate(loader):
    model.eval()
    total_loss = 0.0
    total_acc = 0.0
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            yb = yb.to(device)
            preds = model(xb)
            loss = criterion(preds, yb)
            acc = accuracy(preds, yb)
            total_loss += loss.item()
            total_acc += acc.item()
    return total_loss / len(loader), total_acc / len(loader)

val_loss, val_acc = evaluate(val_loader)
test_loss, test_acc = evaluate(test_loader)

print(f"Validation - Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")
print(f"Test        - Loss: {test_loss:.4f}, Acc: {test_acc:.4f}")
# Out:
# Validation - Loss: 0.7171, Acc: 0.8287
# Test        - Loss: 0.7436, Acc: 0.8222

# %%
# -------------------------------------------------------------
# 9. Komoran 기반 토크나이저 모델 (SentencePiece 결과와 비교용)
# -------------------------------------------------------------
from collections import Counter
try:
    from konlpy.tag import Komoran
except ImportError as exc:
    raise RuntimeError("konlpy가 필요합니다. 먼저 !pip install konlpy 를 실행하세요.") from exc

komoran = Komoran()
PAD_ID_KOM = 0
UNK_ID_KOM = 1
MIN_FREQ = 5

def komoran_tokenize(text):
    return komoran.morphs(str(text))

token_counter = Counter()
for doc in train_df['document']:
    token_counter.update(komoran_tokenize(doc))

komoran_vocab = {"<pad>": PAD_ID_KOM, "<unk>": UNK_ID_KOM}
for token, freq in token_counter.items():
    if freq >= MIN_FREQ and token not in komoran_vocab:
        komoran_vocab[token] = len(komoran_vocab)

def komoran_encode(text):
    ids = [komoran_vocab.get(tok, UNK_ID_KOM) for tok in komoran_tokenize(text)]
    return torch.tensor(ids[:MAX_LEN], dtype=torch.long)

X_train_kom_seq = [komoran_encode(t) for t in train_df['document']]
X_test_kom_seq = [komoran_encode(t) for t in test_df['document']]

X_train_kom_pad = pad_sequence(
    [s[:MAX_LEN] for s in X_train_kom_seq],
    batch_first=True,
    padding_value=PAD_ID_KOM
)
X_test_kom_pad = pad_sequence(
    [s[:MAX_LEN] for s in X_test_kom_seq],
    batch_first=True,
    padding_value=PAD_ID_KOM
)

X_train_k, X_val_k, y_train_k, y_val_k = train_test_split(
    X_train_kom_pad, y_train, test_size=0.2, random_state=42
)

train_loader_kom = DataLoader(TensorDataset(X_train_k, y_train_k), batch_size=64, shuffle=True)
val_loader_kom = DataLoader(TensorDataset(X_val_k, y_val_k), batch_size=64)
test_loader_kom = DataLoader(TensorDataset(X_test_kom_pad, y_test), batch_size=64)

komoran_model = SentimentLSTM(
    vocab_size=len(komoran_vocab),
    embedding_dim=128,
    hidden_dim=32
).to(device)

kom_optimizer = optim.Adam(komoran_model.parameters(), lr=1e-3)

def run_epoch(model, loader, optimizer=None):
    is_train = optimizer is not None
    model.train() if is_train else model.eval()
    total_loss, total_acc = 0.0, 0.0
    ctx = torch.enable_grad() if is_train else torch.no_grad()
    with ctx:
        for xb, yb in loader:
            xb = xb.to(device)
            yb = yb.to(device)
            preds = model(xb)
            loss = criterion(preds, yb)
            acc = accuracy(preds, yb)
            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            total_loss += loss.item()
            total_acc += acc.item()
    return total_loss / len(loader), total_acc / len(loader)

for epoch in range(5):
    train_loss, train_acc = run_epoch(komoran_model, train_loader_kom, kom_optimizer)
    val_loss, val_acc = run_epoch(komoran_model, val_loader_kom)
    print(f'[Komoran] Epoch {epoch+1} | Train {train_loss:.4f}/{train_acc:.4f} | Val {val_loss:.4f}/{val_acc:.4f}')

val_loss_k, val_acc_k = run_epoch(komoran_model, val_loader_kom)
test_loss_k, test_acc_k = run_epoch(komoran_model, test_loader_kom)
print(f'[Komoran] Validation - Loss: {val_loss_k:.4f}, Acc: {val_acc_k:.4f}')
print(f'[Komoran] Test        - Loss: {test_loss_k:.4f}, Acc: {test_acc_k:.4f}')
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 10
#       7 except ImportError as exc:
#       8     raise RuntimeError("konlpy가 필요합니다. 먼저 !pip install konlpy 를 실행하세요.") from exc
# ---> 10 komoran = Komoran()
#      11 PAD_ID_KOM = 0
#      12 UNK_ID_KOM = 1
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages/konlpy/tag/_komoran.py:56, in Komoran.__init__(self, jvmpath, userdic, modelpath, max_heap_size)
#      54 def __init__(self, jvmpath=None, userdic=None, modelpath=None, max_heap_size=1024):
#      55     if not jpype.isJVMStarted():
# ---> 56         jvm.init_jvm(jvmpath, max_heap_size)
#      58     if modelpath:
#      59         self.modelpath = modelpath
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages/konlpy/jvm.py:55, in init_jvm(jvmpath, max_heap_size)
#      52 args = [javadir, os.sep]
#      53 classpath = [f.format(*args) for f in folder_suffix]
# ---> 55 jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      57 # NOTE: Temporary patch for Issue #76. Erase when possible.
#      58 if sys.platform == 'darwin'\
#      59         and jvmpath.find('1.8.0') > 0\
#      60         and jvmpath.endswith('libjvm.dylib'):
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages/jpype/_jvmfinder.py:70, in getDefaultJVMPath()
#      68 else:
#      69     finder = LinuxJVMFinder()
# ---> 70 return finder.get_jvm_path()
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages/jpype/_jvmfinder.py:184, in JVMFinder.get_jvm_path(self)
#     182 for method in self._methods:
#     183     try:
# --> 184         jvm = method()
#     186         # If found check the architecture
#     187         if jvm:
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/site-packages/jpype/_jvmfinder.py:311, in DarwinJVMFinder._javahome_binary(self)
#     309 # TODO: check if the java_home tool is still available and fix the version boundaries.
#     310 if Version('10.6') <= current:  # < Version('10.9'):
# --> 311     return subprocess.check_output(
#     312         ['/usr/libexec/java_home']).strip()
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/subprocess.py:472, in check_output(timeout, *popenargs, **kwargs)
#     469         empty = b''
#     470     kwargs['input'] = empty
# --> 472 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     473            **kwargs).stdout
#
# File /opt/homebrew/anaconda3/envs/test/lib/python3.14/subprocess.py:577, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     575     retcode = process.poll()
#     576     if check and retcode:
# --> 577         raise CalledProcessError(retcode, process.args,
#     578                                  output=stdout, stderr=stderr)
#     579 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/libexec/java_home']' returned non-zero exit status 1.
